# %%
# %pip install pandas numpy matplotlib openpyxl

# %%
import pandas as pd

# Read the CSV file and load it into a DataFrame
xls = pd.ExcelFile("enrollments_dataset.xlsx")
xls.sheet_names
# Out:
# ['Enrollments by Parents']

# %%
df = xls.parse("Enrollments by Parents")

# %%
df.sample(10)
# Out:
#                Timestamp Parent name Child Name   Age  \
# 4481 2024-10-23 03:08:00        Olga      Carla  12.0
# 4332 2024-10-02 05:29:00       Tanya     Harper  12.0
# 595  2024-01-24 04:54:00       Sheri      Ayden  12.0
# 4158 2024-09-15 04:25:00      Brandy       Evan  10.0
# 3095 2024-05-28 18:51:00    Kathleen  Millicent  10.0
# 1332 2024-02-12 20:38:00     Leandra     Aubrey   7.0
# 5442                 NaT         NaN        NaN   NaN
# 5173                 NaT         NaN        NaN   NaN
# 3882 2024-08-10 20:54:00       Hadia       Eesa   8.0
# 1497 2024-02-15 07:58:00       Kelly     Declan   8.0
#
#      Communication Preference      Teacher Name               Source  \
# 4481                    Email    Nicole Pauling   Friends and Family
# 4332                    Email     Austin Stites             Facebook
# 595                       NaN        Misses Dee   Friends and Family
# 4158                     Text      Ms. Courtney             Facebook
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6509 entries, 0 to 6508
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  4392 non-null   datetime64[ns]
#  1   Parent name                4817 non-null   object
#  2   Child Name                 4817 non-null   object
#  3   Age                        4814 non-null   float64
#  4   Communication Preference   3249 non-null   object
#  5   Teacher Name               4784 non-null   object
#  6   Source                     4807 non-null   object
#  7   Source details             3750 non-null   object
#  8   Class ID                   4783 non-null   object
#  9   Type                       4783 non-null   object
#  10  Class name                 4783 non-null   object
#  11  Date                       4782 non-null   datetime64[ns]
#  12  Day                        4783 non-null   object
# ...

# %%
df.describe()
# Out:
#                            Timestamp           Age  \
# count                           4392  4.814000e+03
# mean   2024-05-14 08:34:44.426229504  7.369323e+07
# min              2024-01-11 22:23:00  1.000000e+00
# 25%              2024-02-16 09:25:00  9.000000e+00
# 50%              2024-04-19 06:33:00  1.000000e+01
# 75%              2024-07-30 11:37:15  1.100000e+01
# max              2024-11-21 05:08:00  3.547592e+11
# std                              NaN  5.113057e+09
#
#                                 Date  Score - Concept  Score - Interesting  \
# count                           4782      4582.000000          4582.000000
# mean   2024-06-06 02:50:44.416562176         0.611742             0.609777
# min              2024-01-02 00:00:00         0.000000             0.000000
# 25%              2024-03-08 00:00:00         0.000000             0.000000
# 50%              2024-05-20 00:00:00         0.000000             0.000000
# ...

# %%
df.shape
# Out:
# (6509, 38)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Parent name', 'Child Name', 'Age',
#        'Communication Preference', 'Teacher Name', 'Source', 'Source details',
#        'Class ID', 'Type', 'Class name', 'Date', 'Day', 'Start time (in PST)',
#        'End time (in PST)', 'Want another slot', 'Country', 'Region', 'City',
#        'Timezone', 'Phase Mapping', 'Topics', 'Attended?', 'Concepts',
#        'Interesting', 'Another class', 'Score - Concept',
#        'Score - Interesting', 'Score - Another class', 'Yes', 'Maybe', 'No',
#        'Final score', 'ID for sequential classes', 'Class Part Number',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Timestamp                    2117
# Parent name                  1692
# Child Name                   1692
# Age                          1695
# Communication Preference     3260
# Teacher Name                 1725
# Source                       1702
# Source details               2759
# Class ID                     1726
# Type                         1726
# Class name                   1726
# Date                         1727
# Day                          1726
# Start time (in PST)          1726
# End time (in PST)            1726
# Want another slot            6315
# Country                      2464
# Region                       2551
# City                         2317
# Timezone                     1843
# Phase Mapping                1748
# Topics                       1993
# Attended?                    1860
# Concepts                     5020
# Interesting                  5017
# Another class                5019
# Score - Concept              1927
# ...

# %%
# Drop irrelevant or mostly empty columns
df_cleaned = df.drop(
    columns=["Unnamed: 35", "Unnamed: 36", "Unnamed: 37", "Yes", "Maybe", "No"]
)

# Check missing values percentage
missing_values = df_cleaned.isnull().sum() / len(df_cleaned) * 100

# Display columns with high missing values (>40%)
missing_values[missing_values > 40]
# Out:
# Communication Preference     50.084498
# Source details               42.387464
# Want another slot            97.019511
# Concepts                     77.123982
# Interesting                  77.077892
# Another class                77.108619
# ID for sequential classes    43.908434
# Class Part Number            44.353971
# dtype: float64
